# %% [markdown]
# #### Handling Imbalanced Datasets

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C:/Users/user/DATA_SCIENCE/Feature_Engineering/Datasets/CreditCard/creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.Class.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# Counting the number of each feature in the category
#  From the result, there is a very big difference between the Fraud and non-fraud datasets
df.Class.value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# Separating the dependent and Independent features

X=df.drop('Class', axis=1)
y=df.Class

# %%
X
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
print(X.shape)
print(y.shape)
# Out:
# (284807, 30)
# (284807,)

# %%
# Using diffrent models to obtain results on effects of imbalanced data
# Logistic Regression

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.model_selection import KFold, GridSearchCV

# %%
log_class=LogisticRegression()
grid={'C':10.0 ** np.arange(-2,3), 'penalty':['l1','l2']}
cv=KFold(n_splits=5,random_state=None,shuffle=False)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.7)

# %%
clf=GridSearchCV(log_class,grid,cv=cv,n_jobs=1,scoring='f1_macro')
clf.fit(X_train,y_train)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
y_pred=clf.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[85243    41]
#  [   52   107]]
# 0.9989115550718023
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85284
#            1       0.72      0.67      0.70       159
#
#     accuracy                           1.00     85443
#    macro avg       0.86      0.84      0.85     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
#Random Forest Classifier

from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()
classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=classifier.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[85273    11]
#  [   39   120]]
# 0.9994148145547324
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85284
#            1       0.92      0.75      0.83       159
#
#     accuracy                           1.00     85443
#    macro avg       0.96      0.88      0.91     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# #### Performing Undersampling
# ###### Reducing the features with maximum labels to fit the number of minimum labels - Not encouraged coz it leads to loss of data

# %%
y_train.value_counts()
# Out:
# Class
# 0    199031
# 1       333
# Name: count, dtype: int64

# %%
from collections import Counter
Counter(y_train)
# Out:
# Counter({0: 199031, 1: 333})

# %%
from imblearn.under_sampling import NearMiss
ns=NearMiss(sampling_strategy=0.8)
X_train_ns,y_train_ns = ns.fit_resample(X_train,y_train)
print('The number of counts before fit {}'.format(Counter(y_train)))
print('The number of counts after fit {}'.format(Counter(y_train_ns)))
# Out:
# The number of counts before fit Counter({0: 199031, 1: 333})
# The number of counts after fit Counter({0: 416, 1: 333})

# %%
#Performing Random Forest Classiefier after balancing the data

from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()
classifier.fit(X_train_ns,y_train_ns)
# Out:
# RandomForestClassifier()

# %%
y_pred=classifier.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[68293 16991]
#  [   11   148]]
# 0.8010135411912035
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89     85284
#            1       0.01      0.93      0.02       159
#
#     accuracy                           0.80     85443
#    macro avg       0.50      0.87      0.45     85443
# weighted avg       1.00      0.80      0.89     85443

# %% [markdown]
# #### CONCLUSION: Introduces many errors, dont use unless the data is very small

# %% [markdown]
# ### Oversampling

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
over_sampler=RandomOverSampler(sampling_strategy=0.5)
X_train_os,y_train_os = over_sampler.fit_resample(X_train,y_train)
print('The number of counts before fit {}'.format(Counter(y_train)))
print('The number of counts after fit {}'.format(Counter(y_train_os)))
# Out:
# The number of counts before fit Counter({0: 199031, 1: 333})
# The number of counts after fit Counter({0: 199031, 1: 99515})

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()
classifier.fit(X_train_os,y_train_os)
# Out:
# RandomForestClassifier()

# %%
y_pred=classifier.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[85273    11]
#  [   37   122]]
# 0.9994382219725431
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85284
#            1       0.92      0.77      0.84       159
#
#     accuracy                           1.00     85443
#    macro avg       0.96      0.88      0.92     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# #### ONCLUSION: Overfitting works better and doesnt need to data loss

# %%
from imblearn.combine import SMOTETomek

# %%
stmek=SMOTETomek(sampling_strategy=0.75)
X_train_st,y_train_st = stmek.fit_resample(X_train,y_train)
print('The number of counts before fit {}'.format(Counter(y_train)))
print('The number of counts after fit {}'.format(Counter(y_train_st)))
# Out:
# The number of counts before fit Counter({0: 199031, 1: 333})
# The number of counts after fit Counter({0: 198290, 1: 148532})

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()
classifier.fit(X_train_st,y_train_st)
# Out:
# RandomForestClassifier()

# %%
y_pred=classifier.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[85263    21]
#  [   28   131]]
# 0.9994265182636377
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85284
#            1       0.86      0.82      0.84       159
#
#     accuracy                           1.00     85443
#    macro avg       0.93      0.91      0.92     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# #### Conclusion-This a combination of Over and Under Sampling and equally works well

# %% [markdown]
# ### Ensemble Technique

# %%
from imblearn.ensemble import EasyEnsembleClassifier

# %%
easy = EasyEnsembleClassifier()
easy.fit(X_train,y_train)
# Out:
# EasyEnsembleClassifier()

# %%
y_pred=classifier.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[85263    21]
#  [   28   131]]
# 0.9994265182636377
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85284
#            1       0.86      0.82      0.84       159
#
#     accuracy                           1.00     85443
#    macro avg       0.93      0.91      0.92     85443
# weighted avg       1.00      1.00      1.00     85443
